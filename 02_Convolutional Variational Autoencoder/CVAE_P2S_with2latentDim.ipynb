# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf; tf.compat.v1.disable_eager_execution()
from keras import backend as K
from keras.layers import Input, Dense, Conv2D, Conv2DTranspose, Flatten, Lambda, Reshape
from keras.models import Model
from keras.losses import binary_crossentropy

# %%
import os
from tqdm import tqdm
import cv2
from google.colab.patches import cv2_imshow
from keras.preprocessing.image import img_to_array
from keras import regularizers
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import keras
from keras.optimizers import rmsprop_v2
import keras
from keras.layers import Conv2DTranspose, ConvLSTM2D, BatchNormalization, TimeDistributed, Conv2D
from keras.models import Sequential, load_model
from keras.layers import LayerNormalization
from skimage import color
from skimage.transform import resize, rotate

# %%
SIZE = 256
# /content/drive/MyDrive/CUHK Dataset/CUHK_testing_cropped_photos
image_path = '/content/drive/MyDrive/CUHK Dataset/CUHK_training_cropped_photos/'
img_array = []

sketch_path = '/content/drive/MyDrive/CUHK Dataset/CUHK_training_cropped_sketches/'
sketch_array = []

test_image_path = '/content/drive/MyDrive/CUHK Dataset/CUHK_testing_cropped_photos/'
test_img_array = []

test_sketch_path = '/content/drive/MyDrive/CUHK Dataset/CUHK_testing_cropped_sketches/'
test_sketch_array = []

# Image and their corresponding file names in a sorted manner based on their names
image_file = sorted(os.listdir(image_path))
sketch_file = sorted(os.listdir(sketch_path))
test_image_file = sorted(os.listdir(test_image_path))
test_sketch_file = sorted(os.listdir(test_sketch_path))

# %%
def image_preprocessing(file_name, img_path, size):
  storage_array = []
  for img_file in tqdm(file_name):
    x = img_path + img_file
    img = (cv2.resize(cv2.imread(x).astype('float32'),(SIZE,SIZE)))/255.0
    storage_array.append(img)
    
  # Returning storage array where we have stored all our pre-processed images
  return np.array(storage_array)

# %%
img_array = image_preprocessing(image_file, image_path, SIZE)
sketch_array = image_preprocessing(sketch_file, sketch_path, SIZE)
test_img_array = image_preprocessing(test_image_file, test_image_path, SIZE)
test_sketch_array = image_preprocessing(test_sketch_file, test_sketch_path, SIZE)
# Out:
# 100%|██████████| 88/88 [00:47<00:00,  1.87it/s]
# 100%|██████████| 88/88 [00:42<00:00,  2.07it/s]
# 100%|██████████| 100/100 [00:02<00:00, 41.90it/s]
# 100%|██████████| 100/100 [00:48<00:00,  2.07it/s]

# %%
# Print the number of colored and sketch images present
print("Total number of Training Colored images:",len(img_array))
print("Total number of Training sketch images:",len(sketch_array))
print("Total number of Testing Colored images:",len(test_img_array))
print("Total number of Testing sketch images:",len(test_sketch_array))
# Out:
# Total number of Training Colored images: 88
# Total number of Training sketch images: 88
# Total number of Testing Colored images: 100
# Total number of Testing sketch images: 100

# %%
# Converting the image arrays into numpy for easy processing 
img_array_n = np.array(img_array)
sketch_array_n = np.array(sketch_array)

test_img_array_n = np.array(test_img_array)
test_sketch_array_n = np.array(test_sketch_array)

# Printing the shapes of the image 
print("The shape of the train colored image array is:", img_array_n.shape)
print("The shape of the train sketched image array is:", sketch_array_n.shape)

print("The shape of the test colored image array is:", test_img_array_n.shape)
print("The shape of the test sketched image array is:", test_sketch_array_n.shape)
# Out:
# The shape of the train colored image array is: (88, 256, 256, 3)
# The shape of the train sketched image array is: (88, 256, 256, 3)
# The shape of the test colored image array is: (100, 256, 256, 3)
# The shape of the test sketched image array is: (100, 256, 256, 3)

# %%
# Plotting the training images to see
some_photos = np.concatenate([i for i in img_array_n[:5]],axis=1)
some_sketches = np.concatenate([i for i in sketch_array_n[:5]],axis=1)
plt.figure(figsize=(20,10))
plt.imshow(np.concatenate([some_photos,some_sketches]))
plt.axis("OFF")
plt.show()

# %%
# Plotting the testing images to see
some_photos = np.concatenate([i for i in test_img_array_n[:10]],axis=1)
some_sketches = np.concatenate([i for i in test_sketch_array_n[:10]],axis=1)
plt.figure(figsize=(20,10))
plt.imshow(np.concatenate([some_photos,some_sketches]))
plt.axis("OFF")
plt.show()

# %%
(X_train, y_train), (X_test, y_test) = (img_array_n, sketch_array_n), (test_img_array_n, test_sketch_array_n)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((88, 256, 256, 3), (88, 256, 256, 3), (100, 256, 256, 3), (100, 256, 256, 3))

# %% [markdown]
# ## Construction of Encoder

# %%
img_height   = X_train.shape[1]    # 256
img_width    = X_train.shape[2]    # 256
num_channels = X_train.shape[3]    # 3

input_shape =  (img_height, img_width, num_channels)   # (256, 256, 3) 
latent_dim = 2   # Dimension of the latent space

# %%
encoder_input = Input(shape=input_shape)

encoder_conv = Conv2D(filters=8, kernel_size=3, strides=2, padding='same', activation='relu')(encoder_input)

encoder_conv = Conv2D(filters=16, kernel_size=3, strides=2, padding='same', activation='relu')(encoder_conv)
encoder_conv = keras.layers.LeakyReLU()(encoder_conv)

encoder_conv = Conv2D(filters=32, kernel_size=3, strides=2, padding='same', activation='relu')(encoder_conv)
encoder_conv = keras.layers.BatchNormalization()(encoder_conv)
encoder_conv = keras.layers.LeakyReLU()(encoder_conv)

encoder_conv = Conv2D(filters=64, kernel_size=3, strides=2, padding='same', activation='relu')(encoder_conv)
encoder_conv = keras.layers.LeakyReLU()(encoder_conv)

encoder_conv = Conv2D(filters=128, kernel_size=3, strides=2, padding='same', activation='relu')(encoder_conv)
encoder_conv = keras.layers.BatchNormalization()(encoder_conv)
encoder_conv = keras.layers.LeakyReLU()(encoder_conv)

encoder_conv = Conv2D(filters=256, kernel_size=3, strides=2, padding='same', activation='relu')(encoder_conv)
encoder_conv = keras.layers.BatchNormalization()(encoder_conv)
encoder_conv = keras.layers.LeakyReLU()(encoder_conv)

encoder_conv = Conv2D(filters=512, kernel_size=3, strides=2, padding='same', activation='relu')(encoder_conv)
encoder_conv = keras.layers.BatchNormalization()(encoder_conv)
encoder_conv = keras.layers.LeakyReLU()(encoder_conv)

encoder = Flatten()(encoder_conv)

mu = Dense(latent_dim)(encoder)
sigma = Dense(latent_dim)(encoder)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/layers/normalization/batch_normalization.py:532: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ## To determine the values in the latent space layer

# %%
def compute_latent(x):
    mu, sigma = x
    batch = K.shape(mu)[0]
    dim = K.int_shape(mu)[1]
    eps = K.random_normal(shape=(batch,dim))
    return mu + K.exp(sigma/2)*eps

# %% [markdown]
# ## Reparameterization

# %%
latent_space = Lambda(compute_latent, output_shape=(latent_dim,))([mu, sigma])

# %%
conv_shape = K.int_shape(encoder_conv)

# %%
conv_shape
# Out:
# (None, 2, 2, 512)

# %% [markdown]
# ## Construction of Decoder

# %%
decoder_input = Input(shape=(latent_dim,))

decoder = Dense(conv_shape[1]*conv_shape[2]*conv_shape[3], activation='relu')(decoder_input)

decoder = Reshape((conv_shape[1], conv_shape[2], conv_shape[3]))(decoder)

decoder_conv = Conv2DTranspose(filters=512, kernel_size=3, strides=2, padding='same', activation='relu')(decoder)
decoder_conv = keras.layers.Dropout(0.1)(decoder_conv)
decoder_conv = keras.layers.LeakyReLU()(decoder_conv)

decoder_conv = Conv2DTranspose(filters=256, kernel_size=3, strides=2, padding='same', activation='relu')(decoder_conv)
decoder_conv = keras.layers.LeakyReLU()(decoder_conv)

decoder_conv = Conv2DTranspose(filters=128, kernel_size=3, strides=2, padding='same', activation='relu')(decoder_conv)
decoder_conv = keras.layers.Dropout(0.1)(decoder_conv)
decoder_conv = keras.layers.LeakyReLU()(decoder_conv)

decoder_conv = Conv2DTranspose(filters=64, kernel_size=3, strides=2, padding='same', activation='relu')(decoder_conv)
decoder_conv = keras.layers.LeakyReLU()(decoder_conv)

decoder_conv = Conv2DTranspose(filters=32, kernel_size=3, strides=2, padding='same', activation='relu')(decoder_conv)
decoder_conv = keras.layers.LeakyReLU()(decoder_conv)

decoder_conv = Conv2DTranspose(filters=16, kernel_size=3, strides=2, padding='same', activation='relu')(decoder_conv)
decoder_conv = keras.layers.LeakyReLU()(decoder_conv)

decoder_conv = Conv2DTranspose(filters=8, kernel_size=3, strides=2, padding='same', activation='relu')(decoder_conv)

decoder_conv =  Conv2DTranspose(filters=num_channels, kernel_size=3, padding='same', activation='sigmoid')(decoder_conv)

# %% [markdown]
# ## Connecting the encoder and decoder

# %%
encoder = Model(encoder_input, latent_space)
decoder = Model(decoder_input, decoder_conv)

# %% [markdown]
# ## The output of vae model is the output of decoder in which its input is taken from the output of encoder

# %%
vae = Model(encoder_input, decoder(encoder(encoder_input)))

# %% [markdown]
# ## Summary of autoencoder

# %%
vae.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  model (Functional)          (None, 2)                 1585620
#
#  model_1 (Functional)        (None, 256, 256, 3)       3939155
#
# =================================================================
# Total params: 5,524,775
# Trainable params: 5,522,919
# Non-trainable params: 1,856
# _________________________________________________________________

# %% [markdown]
# ## Summary of encoder

# %%
encoder.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 8)  224         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 16)   1168        ['conv2d[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 64, 64, 16)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 32)   4640        ['leaky_re_lu[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 32)  128         ['conv2d_2[0][0]']
#  alization)
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 32, 32, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 16, 16, 64)   18496       ['leaky_re_lu_1[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 16, 16, 64)   0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 8, 8, 128)    73856       ['leaky_re_lu_2[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 8, 8, 128)   512         ['conv2d_4[0][0]']
#  rmalization)
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 8, 8, 128)    0           ['batch_normalization_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 4, 4, 256)    295168      ['leaky_re_lu_3[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 4, 4, 256)   1024        ['conv2d_5[0][0]']
#  rmalization)
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 4, 4, 256)    0           ['batch_normalization_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 2, 2, 512)    1180160     ['leaky_re_lu_4[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 2, 2, 512)   2048        ['conv2d_6[0][0]']
#  rmalization)
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 2, 2, 512)    0           ['batch_normalization_3[0][0]']
#
#  flatten (Flatten)              (None, 2048)         0           ['leaky_re_lu_5[0][0]']
#
#  dense (Dense)                  (None, 2)            4098        ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 2)            4098        ['flatten[0][0]']
#
#  lambda (Lambda)                (None, 2)            0           ['dense[0][0]',
#                                                                   'dense_1[0][0]']
#
# ==================================================================================================
# Total params: 1,585,620
# Trainable params: 1,583,764
# Non-trainable params: 1,856
# __________________________________________________________________________________________________

# %% [markdown]
# ## Summary of decoder

# %%
decoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_2 (Dense)             (None, 2048)              6144
#
#  reshape (Reshape)           (None, 2, 2, 512)         0
#
#  conv2d_transpose (Conv2DTra  (None, 4, 4, 512)        2359808
#  nspose)
#
#  dropout (Dropout)           (None, 4, 4, 512)         0
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 4, 4, 512)         0
#
#  conv2d_transpose_1 (Conv2DT  (None, 8, 8, 256)        1179904
#  ranspose)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 8, 8, 256)         0
#
#  conv2d_transpose_2 (Conv2DT  (None, 16, 16, 128)      295040
#  ranspose)
#
#  dropout_1 (Dropout)         (None, 16, 16, 128)       0
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 16, 16, 128)       0
#
#  conv2d_transpose_3 (Conv2DT  (None, 32, 32, 64)       73792
#  ranspose)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 32, 32, 64)        0
#
#  conv2d_transpose_4 (Conv2DT  (None, 64, 64, 32)       18464
#  ranspose)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 64, 64, 32)        0
#
#  conv2d_transpose_5 (Conv2DT  (None, 128, 128, 16)     4624
#  ranspose)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 128, 128, 16)      0
#
#  conv2d_transpose_6 (Conv2DT  (None, 256, 256, 8)      1160
#  ranspose)
#
#  conv2d_transpose_7 (Conv2DT  (None, 256, 256, 3)      219
#  ranspose)
#
# =================================================================
# Total params: 3,939,155
# Trainable params: 3,939,155
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Defining loss function

# %%
def kl_reconstruction_loss(true, pred):    # Reconstruction loss
    reconstruction_loss = binary_crossentropy(K.flatten(true), K.flatten(pred)) * img_width * img_height    
    
    # KL divergence loss
    kl_loss = 1 + sigma - K.square(mu) - K.exp(sigma)
    kl_loss = K.sum(kl_loss, axis=-1)
    kl_loss *= -0.5    
    
    # Total loss = 50% rec + 50% KL divergence loss
    return K.mean(reconstruction_loss + kl_loss)

# %% [markdown]
# ## Compiling the model

# %%
vae.compile(optimizer='adam', loss=kl_reconstruction_loss)

# %% [markdown]
# ## Training the model

# %%
history = vae.fit(x=X_train, y=y_train, epochs=500, batch_size=16, validation_data=(X_test,y_test))
# Out:
# Train on 88 samples, validate on 100 samples
# Epoch 1/500
# 88/88 [==============================] - ETA: 0s - loss: 44819.5455
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2057: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 88/88 [==============================] - 15s 168ms/sample - loss: 44819.5455 - val_loss: 44683.7113
# Epoch 2/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 39745.3210 - val_loss: 43271.6136
# Epoch 3/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 34177.7077 - val_loss: 41846.2031
# Epoch 4/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 29291.7711 - val_loss: 40140.9947
# Epoch 5/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 26587.9879 - val_loss: 39171.0317
# Epoch 6/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 25309.6570 - val_loss: 38452.8531
# Epoch 7/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 24693.2962 - val_loss: 39310.3434
# Epoch 8/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 24384.6562 - val_loss: 38322.0750
# Epoch 9/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 23962.3812 - val_loss: 37048.9881
# Epoch 10/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 23693.5858 - val_loss: 35684.8497
# Epoch 11/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 23545.7202 - val_loss: 36050.0067
# Epoch 12/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 23298.2301 - val_loss: 36349.7578
# Epoch 13/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 23178.4657 - val_loss: 34361.3364
# Epoch 14/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 23332.0781 - val_loss: 34370.1591
# Epoch 15/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 23123.7670 - val_loss: 34881.2850
# Epoch 16/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 22956.7557 - val_loss: 35187.8139
# Epoch 17/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 22849.4183 - val_loss: 33200.3557
# Epoch 18/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 22705.3121 - val_loss: 33141.3227
# Epoch 19/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 22605.0540 - val_loss: 33007.2145
# Epoch 20/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 22512.6307 - val_loss: 31658.7682
# Epoch 21/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 22686.4945 - val_loss: 31405.9161
# Epoch 22/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 22592.4118 - val_loss: 32779.4774
# Epoch 23/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 22456.9680 - val_loss: 32425.9388
# Epoch 24/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 22408.0589 - val_loss: 31671.2170
# Epoch 25/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 22344.2173 - val_loss: 31170.4567
# Epoch 26/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 22623.5055 - val_loss: 30242.4983
# Epoch 27/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 22630.7791 - val_loss: 30708.0958
# Epoch 28/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 22363.7152 - val_loss: 30434.4012
# Epoch 29/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 22222.9945 - val_loss: 29104.7930
# Epoch 30/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 22551.9070 - val_loss: 28927.1549
# Epoch 31/500
# 88/88 [==============================] - 0s 4ms/sample - loss: 22271.8043 - val_loss: 29509.1577
# Epoch 32/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 22181.3919 - val_loss: 28623.9052
# Epoch 33/500
# 88/88 [==============================] - 0s 4ms/sample - loss: 21914.0515 - val_loss: 28396.8702
# Epoch 34/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21875.9936 - val_loss: 28376.2837
# Epoch 35/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21883.6889 - val_loss: 28321.9770
# Epoch 36/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21872.0831 - val_loss: 28799.5902
# Epoch 37/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 22315.2654 - val_loss: 27780.6428
# Epoch 38/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 22314.2285 - val_loss: 29149.5842
# Epoch 39/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21993.9155 - val_loss: 28231.9109
# Epoch 40/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 22071.2587 - val_loss: 27319.4854
# Epoch 41/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 22148.7040 - val_loss: 29379.5136
# Epoch 42/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21831.1246 - val_loss: 26904.0360
# Epoch 43/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21841.5082 - val_loss: 26725.1291
# Epoch 44/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21871.5790 - val_loss: 27006.6789
# Epoch 45/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21950.0827 - val_loss: 26619.1136
# Epoch 46/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21818.3283 - val_loss: 26715.1686
# Epoch 47/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21658.4302 - val_loss: 26528.4829
# Epoch 48/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21634.9673 - val_loss: 26594.5531
# Epoch 49/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21663.5302 - val_loss: 26602.7034
# Epoch 50/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21580.2468 - val_loss: 27288.7203
# Epoch 51/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21615.4233 - val_loss: 27597.3877
# Epoch 52/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21655.0142 - val_loss: 27513.0222
# Epoch 53/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21524.7175 - val_loss: 27136.2468
# Epoch 54/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21554.3130 - val_loss: 26854.9306
# Epoch 55/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21629.2848 - val_loss: 27233.0134
# Epoch 56/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21704.1035 - val_loss: 27431.1748
# Epoch 57/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21984.7965 - val_loss: 26910.3269
# Epoch 58/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21690.8793 - val_loss: 26965.7325
# Epoch 59/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21566.3267 - val_loss: 26920.1056
# Epoch 60/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21360.2825 - val_loss: 26979.8363
# Epoch 61/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21389.9513 - val_loss: 26988.4719
# Epoch 62/500
# 88/88 [==============================] - 0s 4ms/sample - loss: 21344.6701 - val_loss: 27164.6831
# Epoch 63/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21310.6168 - val_loss: 27361.0775
# Epoch 64/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21350.4467 - val_loss: 27572.1225
# Epoch 65/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21371.9464 - val_loss: 27137.4153
# Epoch 66/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21327.0664 - val_loss: 27273.6677
# Epoch 67/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21300.5220 - val_loss: 28299.3655
# Epoch 68/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21444.9244 - val_loss: 27062.0447
# Epoch 69/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21271.9773 - val_loss: 27116.8225
# Epoch 70/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21136.9155 - val_loss: 27857.4905
# Epoch 71/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21162.0707 - val_loss: 27389.8862
# Epoch 72/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21146.3888 - val_loss: 27378.4259
# Epoch 73/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21144.1094 - val_loss: 27161.2545
# Epoch 74/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21276.2131 - val_loss: 27448.1770
# Epoch 75/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21121.6452 - val_loss: 27636.7163
# Epoch 76/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21235.8697 - val_loss: 27341.4158
# Epoch 77/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21230.3741 - val_loss: 27490.6413
# Epoch 78/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21225.3743 - val_loss: 26812.8748
# Epoch 79/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21234.3928 - val_loss: 27043.3884
# Epoch 80/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21273.7328 - val_loss: 27692.9023
# Epoch 81/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21273.1268 - val_loss: 27410.5758
# Epoch 82/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21120.4048 - val_loss: 27480.7470
# Epoch 83/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21112.3535 - val_loss: 27645.0462
# Epoch 84/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21290.5099 - val_loss: 27531.0485
# Epoch 85/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21124.6779 - val_loss: 28581.3130
# Epoch 86/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21174.9048 - val_loss: 28067.2905
# Epoch 87/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21141.5154 - val_loss: 27333.4987
# Epoch 88/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21115.5071 - val_loss: 26906.8634
# Epoch 89/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21075.3885 - val_loss: 27317.8856
# Epoch 90/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 21083.7070 - val_loss: 27358.0108
# Epoch 91/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20929.4570 - val_loss: 27707.1316
# Epoch 92/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20855.4339 - val_loss: 27370.3411
# Epoch 93/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20781.5815 - val_loss: 27697.7909
# Epoch 94/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20848.4205 - val_loss: 27706.3176
# Epoch 95/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20898.6325 - val_loss: 26975.3663
# Epoch 96/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20761.9231 - val_loss: 26826.1113
# Epoch 97/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20967.3104 - val_loss: 26910.2148
# Epoch 98/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20792.6431 - val_loss: 27698.8215
# Epoch 99/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20860.5089 - val_loss: 27253.2280
# Epoch 100/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20742.9217 - val_loss: 26918.6362
# Epoch 101/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20677.6254 - val_loss: 26946.5318
# Epoch 102/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20637.8746 - val_loss: 27326.6209
# Epoch 103/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20705.4290 - val_loss: 27124.4531
# Epoch 104/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20771.0820 - val_loss: 26941.9861
# Epoch 105/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20679.1056 - val_loss: 26900.0873
# Epoch 106/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20671.1374 - val_loss: 27215.4111
# Epoch 107/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20652.9361 - val_loss: 26860.6492
# Epoch 108/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20670.2012 - val_loss: 27021.1318
# Epoch 109/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20601.8713 - val_loss: 28039.1865
# Epoch 110/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20644.3956 - val_loss: 27375.6000
# Epoch 111/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20603.1426 - val_loss: 27238.7095
# Epoch 112/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20565.6651 - val_loss: 27466.4623
# Epoch 113/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20548.6369 - val_loss: 27971.8742
# Epoch 114/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20652.2386 - val_loss: 26961.4625
# Epoch 115/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20694.2424 - val_loss: 27216.5569
# Epoch 116/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20700.7102 - val_loss: 26777.5211
# Epoch 117/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20619.4869 - val_loss: 26947.4936
# Epoch 118/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20530.7141 - val_loss: 27420.0744
# Epoch 119/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20430.3825 - val_loss: 27444.7142
# Epoch 120/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20460.7383 - val_loss: 27482.0064
# Epoch 121/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20603.6193 - val_loss: 28035.7805
# Epoch 122/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20709.3416 - val_loss: 27653.4145
# Epoch 123/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20634.1765 - val_loss: 27066.9605
# Epoch 124/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20663.5142 - val_loss: 27056.7366
# Epoch 125/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20854.2628 - val_loss: 27060.6864
# Epoch 126/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20902.8327 - val_loss: 27116.8049
# Epoch 127/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20712.7482 - val_loss: 30694.1620
# Epoch 128/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20652.0178 - val_loss: 28206.0593
# Epoch 129/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20580.6598 - val_loss: 26733.2700
# Epoch 130/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20653.0721 - val_loss: 26716.2745
# Epoch 131/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20496.4785 - val_loss: 27541.4036
# Epoch 132/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20396.2383 - val_loss: 27236.4435
# Epoch 133/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20493.8050 - val_loss: 27567.5330
# Epoch 134/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20600.8162 - val_loss: 27781.9891
# Epoch 135/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20534.6612 - val_loss: 27609.4727
# Epoch 136/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20430.9538 - val_loss: 27350.8394
# Epoch 137/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20511.2198 - val_loss: 26886.4341
# Epoch 138/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20685.6788 - val_loss: 27882.5922
# Epoch 139/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20495.8251 - val_loss: 28455.4486
# Epoch 140/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20611.7653 - val_loss: 27853.1139
# Epoch 141/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20447.8910 - val_loss: 27511.4651
# Epoch 142/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20321.0826 - val_loss: 26874.8298
# Epoch 143/500
# 88/88 [==============================] - 0s 4ms/sample - loss: 20370.9632 - val_loss: 26877.1625
# Epoch 144/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20525.0451 - val_loss: 27309.4602
# Epoch 145/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20464.9022 - val_loss: 28132.8691
# Epoch 146/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20523.2791 - val_loss: 26894.4452
# Epoch 147/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20412.8498 - val_loss: 27150.9191
# Epoch 148/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20319.0952 - val_loss: 27112.2263
# Epoch 149/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20360.4769 - val_loss: 27081.9820
# Epoch 150/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20281.0932 - val_loss: 27388.6870
# Epoch 151/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20247.6270 - val_loss: 27210.8783
# Epoch 152/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20221.3878 - val_loss: 27289.8688
# Epoch 153/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20218.6815 - val_loss: 27000.6109
# Epoch 154/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20219.8246 - val_loss: 27098.3262
# Epoch 155/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20148.2653 - val_loss: 27109.1140
# Epoch 156/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20128.5625 - val_loss: 27025.3682
# Epoch 157/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20075.7369 - val_loss: 27235.2486
# Epoch 158/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20123.5753 - val_loss: 27420.8482
# Epoch 159/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20177.2436 - val_loss: 27289.7746
# Epoch 160/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20049.2287 - val_loss: 27223.9915
# Epoch 161/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20033.1859 - val_loss: 27385.2005
# Epoch 162/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20095.1259 - val_loss: 27344.9209
# Epoch 163/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20012.8093 - val_loss: 27191.5673
# Epoch 164/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19977.5589 - val_loss: 27283.8248
# Epoch 165/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19986.7873 - val_loss: 27803.9234
# Epoch 166/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20015.8072 - val_loss: 27662.1155
# Epoch 167/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19966.5339 - val_loss: 27345.2892
# Epoch 168/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19871.0011 - val_loss: 27760.0371
# Epoch 169/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19946.3043 - val_loss: 28179.5157
# Epoch 170/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19980.6850 - val_loss: 27422.2211
# Epoch 171/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19967.2903 - val_loss: 26919.6294
# Epoch 172/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20041.9854 - val_loss: 27947.6414
# Epoch 173/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19976.6570 - val_loss: 27385.4150
# Epoch 174/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19860.6839 - val_loss: 27486.0266
# Epoch 175/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20025.5391 - val_loss: 27768.4801
# Epoch 176/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19970.5455 - val_loss: 27424.4919
# Epoch 177/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19874.4918 - val_loss: 27743.3364
# Epoch 178/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19880.3881 - val_loss: 27671.4442
# Epoch 179/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19883.6017 - val_loss: 27389.7957
# Epoch 180/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19961.6822 - val_loss: 27949.8021
# Epoch 181/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20141.3235 - val_loss: 27474.2459
# Epoch 182/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20038.6319 - val_loss: 28544.8388
# Epoch 183/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20045.9698 - val_loss: 27949.2870
# Epoch 184/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19904.1403 - val_loss: 27791.4726
# Epoch 185/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19976.6033 - val_loss: 27380.4628
# Epoch 186/500
# 88/88 [==============================] - 0s 4ms/sample - loss: 20603.3130 - val_loss: 28237.7709
# Epoch 187/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20398.4197 - val_loss: 27549.0452
# Epoch 188/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20361.7820 - val_loss: 27609.3494
# Epoch 189/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20324.9744 - val_loss: 26982.8802
# Epoch 190/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20156.8569 - val_loss: 27467.9905
# Epoch 191/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20133.5011 - val_loss: 28202.9369
# Epoch 192/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20176.8665 - val_loss: 27237.8728
# Epoch 193/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20015.3608 - val_loss: 27173.3737
# Epoch 194/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20125.5840 - val_loss: 27728.5964
# Epoch 195/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20099.0497 - val_loss: 28090.1309
# Epoch 196/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20011.3233 - val_loss: 27125.5602
# Epoch 197/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 20015.6594 - val_loss: 26879.0148
# Epoch 198/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19966.9229 - val_loss: 27908.3181
# Epoch 199/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19793.2241 - val_loss: 27285.4210
# Epoch 200/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19851.1143 - val_loss: 27194.2129
# Epoch 201/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19860.1607 - val_loss: 27410.4858
# Epoch 202/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19891.1582 - val_loss: 28498.9141
# Epoch 203/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19834.3517 - val_loss: 28103.0360
# Epoch 204/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19656.6403 - val_loss: 27579.6128
# Epoch 205/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19611.7983 - val_loss: 27517.1803
# Epoch 206/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19590.1779 - val_loss: 27564.2178
# Epoch 207/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19553.1919 - val_loss: 28552.6133
# Epoch 208/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19586.4915 - val_loss: 27821.1255
# Epoch 209/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19502.8180 - val_loss: 27718.2788
# Epoch 210/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19553.9029 - val_loss: 28026.1818
# Epoch 211/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19598.0938 - val_loss: 28441.3453
# Epoch 212/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19654.6158 - val_loss: 27817.7143
# Epoch 213/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19609.1481 - val_loss: 28423.7399
# Epoch 214/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19675.3679 - val_loss: 27578.3547
# Epoch 215/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19613.4549 - val_loss: 27750.6241
# Epoch 216/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19576.3796 - val_loss: 27591.9228
# Epoch 217/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19596.9941 - val_loss: 28721.2639
# Epoch 218/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19633.0238 - val_loss: 28367.4012
# Epoch 219/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19663.5407 - val_loss: 27106.5205
# Epoch 220/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19835.2099 - val_loss: 28497.3555
# Epoch 221/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19703.1751 - val_loss: 29024.2355
# Epoch 222/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19583.4437 - val_loss: 28062.2955
# Epoch 223/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19604.5046 - val_loss: 28088.1905
# Epoch 224/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19622.0123 - val_loss: 27690.0458
# Epoch 225/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19485.4881 - val_loss: 27825.7523
# Epoch 226/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19417.0284 - val_loss: 28451.3703
# Epoch 227/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19496.5352 - val_loss: 27606.2035
# Epoch 228/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19462.3239 - val_loss: 27240.0135
# Epoch 229/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19731.5749 - val_loss: 27436.9736
# Epoch 230/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19740.8086 - val_loss: 28402.4902
# Epoch 231/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19816.4464 - val_loss: 28489.5361
# Epoch 232/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19771.9711 - val_loss: 27621.9634
# Epoch 233/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19566.8817 - val_loss: 27928.5686
# Epoch 234/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19679.7646 - val_loss: 27886.0883
# Epoch 235/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19555.2182 - val_loss: 27975.8212
# Epoch 236/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19497.8374 - val_loss: 27176.6591
# Epoch 237/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19507.5103 - val_loss: 27855.5811
# Epoch 238/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19458.0661 - val_loss: 28447.3457
# Epoch 239/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19512.9975 - val_loss: 28064.7959
# Epoch 240/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19476.5179 - val_loss: 27869.1145
# Epoch 241/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19746.3587 - val_loss: 28052.3491
# Epoch 242/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19570.7617 - val_loss: 28856.3428
# Epoch 243/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19810.7028 - val_loss: 27542.4056
# Epoch 244/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19774.4467 - val_loss: 28037.3194
# Epoch 245/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19644.5827 - val_loss: 27617.2200
# Epoch 246/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19682.3622 - val_loss: 28338.2697
# Epoch 247/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19569.0421 - val_loss: 27615.1178
# Epoch 248/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19504.4640 - val_loss: 28418.3997
# Epoch 249/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19521.3963 - val_loss: 28008.2732
# Epoch 250/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19461.4332 - val_loss: 27624.1411
# Epoch 251/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19407.0817 - val_loss: 28022.7838
# Epoch 252/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19439.3942 - val_loss: 28179.4479
# Epoch 253/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19283.1974 - val_loss: 27974.7320
# Epoch 254/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19176.6712 - val_loss: 28001.6297
# Epoch 255/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19100.0215 - val_loss: 28105.6340
# Epoch 256/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19067.9361 - val_loss: 28181.4067
# Epoch 257/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19138.5067 - val_loss: 28665.1484
# Epoch 258/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19171.6632 - val_loss: 28657.2920
# Epoch 259/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19113.6136 - val_loss: 28060.7869
# Epoch 260/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19244.4638 - val_loss: 27580.1845
# Epoch 261/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19180.3136 - val_loss: 28280.6749
# Epoch 262/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19157.3075 - val_loss: 28100.1641
# Epoch 263/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19204.9844 - val_loss: 28791.7438
# Epoch 264/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19153.9402 - val_loss: 29009.6148
# Epoch 265/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19359.6784 - val_loss: 28024.6389
# Epoch 266/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19365.7156 - val_loss: 28097.8106
# Epoch 267/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19552.1353 - val_loss: 28248.8741
# Epoch 268/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19380.6500 - val_loss: 28225.4138
# Epoch 269/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19345.6884 - val_loss: 27681.4556
# Epoch 270/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19279.8281 - val_loss: 28203.7814
# Epoch 271/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19193.2566 - val_loss: 28147.9840
# Epoch 272/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19128.7994 - val_loss: 27701.3869
# Epoch 273/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19211.9570 - val_loss: 29036.0016
# Epoch 274/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19183.9986 - val_loss: 29058.3663
# Epoch 275/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19124.4741 - val_loss: 28792.7388
# Epoch 276/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19118.4577 - val_loss: 29020.2183
# Epoch 277/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19302.9840 - val_loss: 27806.4540
# Epoch 278/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19234.7134 - val_loss: 28799.9980
# Epoch 279/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19126.5756 - val_loss: 28637.1395
# Epoch 280/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19048.7452 - val_loss: 28622.6428
# Epoch 281/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19117.7411 - val_loss: 27786.5810
# Epoch 282/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19027.4045 - val_loss: 28708.7535
# Epoch 283/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19045.1168 - val_loss: 29716.1431
# Epoch 284/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19292.7638 - val_loss: 28577.1919
# Epoch 285/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19234.5437 - val_loss: 27829.3423
# Epoch 286/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19248.5732 - val_loss: 28761.2323
# Epoch 287/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19064.2092 - val_loss: 28517.2527
# Epoch 288/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18976.8354 - val_loss: 28269.2815
# Epoch 289/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19048.2772 - val_loss: 28592.3547
# Epoch 290/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18984.6206 - val_loss: 28257.9549
# Epoch 291/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18952.1634 - val_loss: 28393.8989
# Epoch 292/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19028.4780 - val_loss: 29141.6639
# Epoch 293/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18977.7518 - val_loss: 28175.8770
# Epoch 294/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19104.4760 - val_loss: 28782.2182
# Epoch 295/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18905.5508 - val_loss: 28795.4109
# Epoch 296/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18859.9229 - val_loss: 28838.2505
# Epoch 297/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18887.7310 - val_loss: 28651.7844
# Epoch 298/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18775.0281 - val_loss: 28709.3566
# Epoch 299/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18819.3814 - val_loss: 28426.5864
# Epoch 300/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18691.0064 - val_loss: 28514.4082
# Epoch 301/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18767.1259 - val_loss: 28815.6889
# Epoch 302/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18806.0646 - val_loss: 29238.7795
# Epoch 303/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18788.0344 - val_loss: 28615.5405
# Epoch 304/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18872.1797 - val_loss: 28445.9209
# Epoch 305/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18908.9109 - val_loss: 28425.2705
# Epoch 306/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18831.8329 - val_loss: 28863.2730
# Epoch 307/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18755.0062 - val_loss: 28988.0192
# Epoch 308/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18735.9709 - val_loss: 28685.8179
# Epoch 309/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18717.3730 - val_loss: 28485.4254
# Epoch 310/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19009.4279 - val_loss: 29471.8737
# Epoch 311/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18867.7273 - val_loss: 29220.5807
# Epoch 312/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18845.3642 - val_loss: 28085.7741
# Epoch 313/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18904.6044 - val_loss: 28546.6741
# Epoch 314/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18942.2468 - val_loss: 29831.9215
# Epoch 315/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19149.1884 - val_loss: 29560.6248
# Epoch 316/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19063.7711 - val_loss: 27943.2855
# Epoch 317/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19067.7717 - val_loss: 28077.4529
# Epoch 318/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19023.7596 - val_loss: 29316.8233
# Epoch 319/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19118.2047 - val_loss: 29735.4215
# Epoch 320/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19003.4405 - val_loss: 28071.5728
# Epoch 321/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19111.1254 - val_loss: 28467.3628
# Epoch 322/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18982.3382 - val_loss: 30233.5166
# Epoch 323/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18942.9071 - val_loss: 28581.0800
# Epoch 324/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18857.2077 - val_loss: 28048.2643
# Epoch 325/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18711.4153 - val_loss: 29888.7305
# Epoch 326/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18789.0298 - val_loss: 29647.0279
# Epoch 327/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18648.1005 - val_loss: 28645.0621
# Epoch 328/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18666.5968 - val_loss: 29331.7602
# Epoch 329/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18594.8260 - val_loss: 29605.2952
# Epoch 330/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18490.8572 - val_loss: 29469.2642
# Epoch 331/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18460.7408 - val_loss: 28661.8764
# Epoch 332/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18489.9002 - val_loss: 29199.5348
# Epoch 333/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18505.9954 - val_loss: 29924.1345
# Epoch 334/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18508.8619 - val_loss: 29364.5070
# Epoch 335/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18544.5355 - val_loss: 28706.8074
# Epoch 336/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18530.7646 - val_loss: 29458.3440
# Epoch 337/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18722.5025 - val_loss: 29421.8441
# Epoch 338/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18625.6467 - val_loss: 28785.4275
# Epoch 339/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18777.7191 - val_loss: 29227.6261
# Epoch 340/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18816.2012 - val_loss: 28814.9958
# Epoch 341/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18884.5439 - val_loss: 29976.2484
# Epoch 342/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19077.3413 - val_loss: 28284.8968
# Epoch 343/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19139.8253 - val_loss: 29193.4182
# Epoch 344/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19073.0266 - val_loss: 28629.1938
# Epoch 345/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 19077.8207 - val_loss: 29381.6127
# Epoch 346/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18841.5289 - val_loss: 28177.9604
# Epoch 347/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18725.4549 - val_loss: 29810.7394
# Epoch 348/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18576.4689 - val_loss: 29384.4306
# Epoch 349/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18545.9190 - val_loss: 28976.8095
# Epoch 350/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18539.3988 - val_loss: 29204.9686
# Epoch 351/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18479.7699 - val_loss: 30071.9301
# Epoch 352/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18496.5852 - val_loss: 29101.9231
# Epoch 353/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18549.3961 - val_loss: 28470.5537
# Epoch 354/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18874.4734 - val_loss: 29348.8289
# Epoch 355/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18726.2628 - val_loss: 29383.2513
# Epoch 356/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18737.6555 - val_loss: 28921.0117
# Epoch 357/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18827.5710 - val_loss: 28986.1164
# Epoch 358/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18881.2601 - val_loss: 29129.6878
# Epoch 359/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18891.3707 - val_loss: 28918.3914
# Epoch 360/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18921.7056 - val_loss: 30389.7582
# Epoch 361/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18921.0920 - val_loss: 28412.9464
# Epoch 362/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18656.6648 - val_loss: 29682.9032
# Epoch 363/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18592.0355 - val_loss: 28951.9152
# Epoch 364/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18515.8938 - val_loss: 28995.3855
# Epoch 365/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18511.0316 - val_loss: 28953.9563
# Epoch 366/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18425.8887 - val_loss: 29513.6895
# Epoch 367/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18387.2733 - val_loss: 29931.7060
# Epoch 368/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18335.9316 - val_loss: 29183.3571
# Epoch 369/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18311.8281 - val_loss: 29750.0930
# Epoch 370/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18335.3008 - val_loss: 29989.9077
# Epoch 371/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18362.4258 - val_loss: 29216.0249
# Epoch 372/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18270.7942 - val_loss: 29678.5727
# Epoch 373/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18459.9318 - val_loss: 30368.0962
# Epoch 374/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18546.4221 - val_loss: 29423.3052
# Epoch 375/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18636.8649 - val_loss: 29458.9439
# Epoch 376/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18735.3409 - val_loss: 29457.8491
# Epoch 377/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18640.2459 - val_loss: 28820.4302
# Epoch 378/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18786.0479 - val_loss: 29783.3745
# Epoch 379/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18477.8189 - val_loss: 29149.2477
# Epoch 380/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18473.7772 - val_loss: 29373.7080
# Epoch 381/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18360.3643 - val_loss: 28795.1237
# Epoch 382/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18323.6648 - val_loss: 29796.2331
# Epoch 383/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18208.9414 - val_loss: 29065.5479
# Epoch 384/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18212.3189 - val_loss: 29407.3598
# Epoch 385/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18119.5078 - val_loss: 30074.8483
# Epoch 386/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18135.3169 - val_loss: 29723.0620
# Epoch 387/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18106.6186 - val_loss: 30078.0383
# Epoch 388/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18073.6097 - val_loss: 29911.6711
# Epoch 389/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18031.0845 - val_loss: 29081.6239
# Epoch 390/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18078.2230 - val_loss: 29972.5492
# Epoch 391/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18084.2852 - val_loss: 30143.1734
# Epoch 392/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18082.4556 - val_loss: 29911.3078
# Epoch 393/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18077.7371 - val_loss: 29629.9097
# Epoch 394/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18106.6420 - val_loss: 29649.6942
# Epoch 395/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18143.1950 - val_loss: 29471.5156
# Epoch 396/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18339.2244 - val_loss: 29695.9802
# Epoch 397/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18365.6460 - val_loss: 30342.2620
# Epoch 398/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18381.5160 - val_loss: 28878.5828
# Epoch 399/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18494.9386 - val_loss: 29292.7850
# Epoch 400/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18408.1619 - val_loss: 30343.7009
# Epoch 401/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18513.0046 - val_loss: 31006.1970
# Epoch 402/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18354.5760 - val_loss: 29286.2869
# Epoch 403/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18383.0128 - val_loss: 29567.7984
# Epoch 404/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18220.9822 - val_loss: 29802.5022
# Epoch 405/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18213.9538 - val_loss: 30365.1080
# Epoch 406/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18269.5700 - val_loss: 29136.9591
# Epoch 407/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18200.0534 - val_loss: 29525.3775
# Epoch 408/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18209.9105 - val_loss: 29777.4902
# Epoch 409/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18072.3750 - val_loss: 29835.3495
# Epoch 410/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18080.0526 - val_loss: 29197.2396
# Epoch 411/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18071.6346 - val_loss: 30486.9375
# Epoch 412/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18145.8189 - val_loss: 30145.3836
# Epoch 413/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18110.2871 - val_loss: 29411.7480
# Epoch 414/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18099.6971 - val_loss: 29572.0418
# Epoch 415/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18153.7486 - val_loss: 29906.4942
# Epoch 416/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18210.1591 - val_loss: 29047.9906
# Epoch 417/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18213.1861 - val_loss: 30620.8691
# Epoch 418/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18185.4375 - val_loss: 29188.4545
# Epoch 419/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18243.7429 - val_loss: 29652.3509
# Epoch 420/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18180.1625 - val_loss: 30452.4927
# Epoch 421/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18150.2060 - val_loss: 29439.7470
# Epoch 422/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18115.6580 - val_loss: 30149.2148
# Epoch 423/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17998.7273 - val_loss: 30369.4394
# Epoch 424/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18021.2933 - val_loss: 29755.2732
# Epoch 425/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18002.2306 - val_loss: 29801.0484
# Epoch 426/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18035.2212 - val_loss: 30588.0547
# Epoch 427/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18087.5504 - val_loss: 29944.6309
# Epoch 428/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18109.8461 - val_loss: 29738.4216
# Epoch 429/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18020.0996 - val_loss: 30436.7028
# Epoch 430/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17976.1101 - val_loss: 29694.3286
# Epoch 431/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17951.2827 - val_loss: 30399.4867
# Epoch 432/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18029.2660 - val_loss: 30168.4477
# Epoch 433/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18020.0886 - val_loss: 30958.6570
# Epoch 434/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17991.6752 - val_loss: 29728.6281
# Epoch 435/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18069.3228 - val_loss: 30327.8091
# Epoch 436/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18144.4709 - val_loss: 31103.3173
# Epoch 437/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18190.4490 - val_loss: 29919.2256
# Epoch 438/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18349.3114 - val_loss: 30403.7177
# Epoch 439/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18292.1875 - val_loss: 29033.3153
# Epoch 440/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18248.3079 - val_loss: 30789.0886
# Epoch 441/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18351.8161 - val_loss: 30047.6558
# Epoch 442/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18264.6019 - val_loss: 29661.8027
# Epoch 443/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18212.7926 - val_loss: 30163.5224
# Epoch 444/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18037.7873 - val_loss: 30097.3666
# Epoch 445/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18072.0582 - val_loss: 30530.8761
# Epoch 446/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18012.2280 - val_loss: 29776.9233
# Epoch 447/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18063.1136 - val_loss: 30342.9597
# Epoch 448/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18075.8329 - val_loss: 30602.8855
# Epoch 449/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18335.5117 - val_loss: 29878.7142
# Epoch 450/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18136.6591 - val_loss: 32770.6343
# Epoch 451/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18316.4929 - val_loss: 31545.7863
# Epoch 452/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18151.3711 - val_loss: 31309.8100
# Epoch 453/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18123.7083 - val_loss: 30105.8798
# Epoch 454/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18040.2214 - val_loss: 30225.6958
# Epoch 455/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17970.3706 - val_loss: 30831.1803
# Epoch 456/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17999.6705 - val_loss: 30684.7076
# Epoch 457/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17962.2646 - val_loss: 30297.1003
# Epoch 458/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18017.9593 - val_loss: 31666.3233
# Epoch 459/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18108.5806 - val_loss: 30746.6295
# Epoch 460/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18099.2674 - val_loss: 29487.5975
# Epoch 461/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18068.7504 - val_loss: 30474.5841
# Epoch 462/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18367.5403 - val_loss: 30140.6959
# Epoch 463/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18208.4023 - val_loss: 30515.4263
# Epoch 464/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18039.0625 - val_loss: 30703.6113
# Epoch 465/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18053.6495 - val_loss: 30931.3718
# Epoch 466/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18255.4613 - val_loss: 30817.5546
# Epoch 467/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18247.9109 - val_loss: 29166.9420
# Epoch 468/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18171.6268 - val_loss: 29788.6344
# Epoch 469/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18128.7283 - val_loss: 30041.1266
# Epoch 470/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18158.5483 - val_loss: 30426.8225
# Epoch 471/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18116.0536 - val_loss: 31408.8679
# Epoch 472/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18262.3363 - val_loss: 29213.8645
# Epoch 473/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18126.0930 - val_loss: 29799.4753
# Epoch 474/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18083.4719 - val_loss: 30476.7669
# Epoch 475/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 18051.3480 - val_loss: 30563.0137
# Epoch 476/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17998.5082 - val_loss: 29779.7313
# Epoch 477/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17972.7131 - val_loss: 30964.2253
# Epoch 478/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17880.6312 - val_loss: 30631.8186
# Epoch 479/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17817.5312 - val_loss: 30104.8802
# Epoch 480/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17735.5794 - val_loss: 30465.3998
# Epoch 481/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17733.4244 - val_loss: 30599.1817
# Epoch 482/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17730.6946 - val_loss: 31256.7513
# Epoch 483/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17695.7124 - val_loss: 30628.5612
# Epoch 484/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17661.8606 - val_loss: 30241.9676
# Epoch 485/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17650.6303 - val_loss: 30977.0939
# Epoch 486/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17635.3361 - val_loss: 31009.2997
# Epoch 487/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17673.8920 - val_loss: 30804.1739
# Epoch 488/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17616.6168 - val_loss: 30207.0573
# Epoch 489/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17608.1051 - val_loss: 30432.6244
# Epoch 490/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17719.8562 - val_loss: 30464.1742
# Epoch 491/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17740.2472 - val_loss: 31033.7359
# Epoch 492/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17690.4419 - val_loss: 30367.9075
# Epoch 493/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17602.6513 - val_loss: 30566.2284
# Epoch 494/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17638.3647 - val_loss: 30891.8834
# Epoch 495/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17700.3143 - val_loss: 30063.2811
# Epoch 496/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17789.7472 - val_loss: 31265.0958
# Epoch 497/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17805.6335 - val_loss: 30942.7759
# Epoch 498/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17682.5131 - val_loss: 31067.7441
# Epoch 499/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17841.9343 - val_loss: 30804.7578
# Epoch 500/500
# 88/88 [==============================] - 0s 5ms/sample - loss: 17969.3333 - val_loss: 31794.3084

# %% [markdown]
# ## Loss value of both train and test data

# %%
plt.plot(history.history['loss'], color='green')
plt.plot(history.history['val_loss'], color='red')
plt.legend(['Training loss', 'Validation loss'])
plt.xlabel('Number of echos')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %% [markdown]
# ## Displaying latent space

# %%
encoded = encoder.predict(X_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %% [markdown]
# ## Decoding data points in latent space

# %%
def display_image_sequence(x_start,y_start,x_end,y_end,no_of_imgs):
    x_axis = np.linspace(x_start,x_end,no_of_imgs)
    y_axis = np.linspace(y_start,y_end,no_of_imgs)
    
    x_axis = x_axis[:, np.newaxis]
    y_axis = y_axis[:, np.newaxis]
    
    new_points = np.hstack((x_axis, y_axis))

    print(new_points.shape)

    new_images = decoder.predict(new_points)
    print(new_images.shape)
    
    new_images = new_images.reshape(new_images.shape[0], new_images.shape[1], new_images.shape[2], new_images.shape[3])
    
    # Display some images
    fig, axes = plt.subplots(ncols=no_of_imgs, sharex=False, sharey=True, figsize=(20, 7))
    counter = 0
    for i in range(no_of_imgs):
        axes[counter].imshow(new_images[i], cmap='gray')
        axes[counter].get_xaxis().set_visible(False)
        axes[counter].get_yaxis().set_visible(False)
        counter += 1
    plt.show()

# %%
for i in range(60,70):
  img_no = i
  fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(5, 3))
  axes[0].imshow(X_test[img_no])
  axes[1].imshow(y_test[img_no])
  axes[2].imshow(vae.predict(X_test)[img_no])
  fig.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
